# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan_approval.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# 0                 27    50.0          False
# 1                 28    55.0          False
# 2                 13    45.0          False
# 3                 29    50.0          False
# 4                  4    25.0          False
# ...              ...     ...            ...
# 1995              13    85.0           True
# 1996              17    40.0          False
# 1997               5    60.0           True
# 1998              35    55.0          False
# 1999               6    20.0          False
#
# [2000 rows x 8 columns]>

# %%
df.shape
# Out:
# (2000, 8)

# %%
df.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# 0                 27    50.0          False
# 1                 28    55.0          False
# 2                 13    45.0          False
# 3                 29    50.0          False
# 4                  4    25.0          False
# ...              ...     ...            ...
# 1995              13    85.0           True
# 1996              17    40.0          False
# 1997               5    60.0           True
# 1998              35    55.0          False
# 1999               6    20.0          False
#
# [2000 rows x 8 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  name              city  income  credit_score  loan_amount  \
# 0        Allison Hill         East Jill  113810           389        39698
# 1        Brandon Hall     New Jamesside   44592           729        15446
# 2        Rhonda Smith      Lake Roberto   33278           584        11189
# 3     Gabrielle Davis  West Melanieview  127196           344        48823
# 4        Valerie Gray         Mariastad   66048           496        47174
# ...               ...               ...     ...           ...          ...
# 1995   James Schaefer         Robertton   92163           770        12251
# 1996        Diana Lin         New Frank   38799           635        48259
# 1997    Brandon Meyer        East Haley   41957           763        16752
# 1998      Jason Price          Adamland  139022           360        24031
# 1999     Nicole Brown    New Nathantown   41188           482        31397
#
#       years_employed  points  loan_approved
# 0                 27    50.0          False
# 1                 28    55.0          False
# 2                 13    45.0          False
# 3                 29    50.0          False
# 4                  4    25.0          False
# ...              ...     ...            ...
# 1995              13    85.0           True
# 1996              17    40.0          False
# 1997               5    60.0           True
# 1998              35    55.0          False
# 1999               6    20.0          False
#
# [2000 rows x 8 columns]>

# %%
df.isnull().sum()
# Out:
# name              0
# city              0
# income            0
# credit_score      0
# loan_amount       0
# years_employed    0
# points            0
# loan_approved     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   object
#  1   city            2000 non-null   object
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), object(2)
# memory usage: 111.5+ KB

# %%
df=pd.get_dummies(df, drop_first=True)

# %%
df.columns
# Out:
# Index(['income', 'credit_score', 'loan_amount', 'years_employed', 'points',
#        'loan_approved', 'name_Aaron Barber', 'name_Aaron Gonzalez',
#        'name_Aaron Jennings', 'name_Aaron Kelly',
#        ...
#        'city_Wilsonton', 'city_Wilsonview', 'city_Wongburgh',
#        'city_Woodsburgh', 'city_Wrightchester', 'city_Yatesbury',
#        'city_Youngbury', 'city_Yumouth', 'city_Zacharyton',
#        'city_Zamoramouth'],
#       dtype='object', length=3886)

# %%
df.info
# Out:
# <bound method DataFrame.info of       income  credit_score  loan_amount  years_employed  points  \
# 0     113810           389        39698              27    50.0
# 1      44592           729        15446              28    55.0
# 2      33278           584        11189              13    45.0
# 3     127196           344        48823              29    50.0
# 4      66048           496        47174               4    25.0
# ...      ...           ...          ...             ...     ...
# 1995   92163           770        12251              13    85.0
# 1996   38799           635        48259              17    40.0
# 1997   41957           763        16752               5    60.0
# 1998  139022           360        24031              35    55.0
# 1999   41188           482        31397               6    20.0
#
#       loan_approved  name_Aaron Barber  name_Aaron Gonzalez  \
# 0             False              False                False
# 1             False              False                False
# 2             False              False                False
# 3             False              False                False
# 4             False              False                False
# ...             ...                ...                  ...
# 1995           True              False                False
# 1996          False              False                False
# 1997           True              False                False
# 1998          False              False                False
# 1999          False              False                False
#
#       name_Aaron Jennings  name_Aaron Kelly  ...  city_Wilsonton  \
# 0                   False             False  ...           False
# 1                   False             False  ...           False
# 2                   False             False  ...           False
# 3                   False             False  ...           False
# 4                   False             False  ...           False
# ...                   ...               ...  ...             ...
# 1995                False             False  ...           False
# 1996                False             False  ...           False
# 1997                False             False  ...           False
# 1998                False             False  ...           False
# 1999                False             False  ...           False
#
#       city_Wilsonview  city_Wongburgh  city_Woodsburgh  city_Wrightchester  \
# 0               False           False            False               False
# 1               False           False            False               False
# 2               False           False            False               False
# 3               False           False            False               False
# 4               False           False            False               False
# ...               ...             ...              ...                 ...
# 1995            False           False            False               False
# 1996            False           False            False               False
# 1997            False           False            False               False
# 1998            False           False            False               False
# 1999            False           False            False               False
#
#       city_Yatesbury  city_Youngbury  city_Yumouth  city_Zacharyton  \
# 0              False           False         False            False
# 1              False           False         False            False
# 2              False           False         False            False
# 3              False           False         False            False
# 4              False           False         False            False
# ...              ...             ...           ...              ...
# 1995           False           False         False            False
# 1996           False           False         False            False
# 1997           False           False         False            False
# 1998           False           False         False            False
# 1999           False           False         False            False
#
#       city_Zamoramouth
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 1995             False
# 1996             False
# 1997             False
# 1998             False
# 1999             False
#
# [2000 rows x 3886 columns]>

# %%
df = pd.read_csv("loan_approval.csv")

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.columns
# Out:
# Index(['income', 'credit_score', 'loan_amount', 'years_employed', 'points',
#        'loan_approved', 'name_Aaron Barber', 'name_Aaron Gonzalez',
#        'name_Aaron Jennings', 'name_Aaron Kelly',
#        ...
#        'city_Wilsonton', 'city_Wilsonview', 'city_Wongburgh',
#        'city_Woodsburgh', 'city_Wrightchester', 'city_Yatesbury',
#        'city_Youngbury', 'city_Yumouth', 'city_Zacharyton',
#        'city_Zamoramouth'],
#       dtype='object', length=3886)

# %%
X = df.drop("loan_approved", axis=1)
Y = df["loan_approved"]

# %%
df.head()
# Out:
#    income  credit_score  loan_amount  years_employed  points  loan_approved  \
# 0  113810           389        39698              27    50.0          False
# 1   44592           729        15446              28    55.0          False
# 2   33278           584        11189              13    45.0          False
# 3  127196           344        48823              29    50.0          False
# 4   66048           496        47174               4    25.0          False
#
#    name_Aaron Barber  name_Aaron Gonzalez  name_Aaron Jennings  \
# 0              False                False                False
# 1              False                False                False
# 2              False                False                False
# 3              False                False                False
# 4              False                False                False
#
#    name_Aaron Kelly  ...  city_Wilsonton  city_Wilsonview  city_Wongburgh  \
# 0             False  ...           False            False           False
# 1             False  ...           False            False           False
# 2             False  ...           False            False           False
# 3             False  ...           False            False           False
# 4             False  ...           False            False           False
#
#    city_Woodsburgh  city_Wrightchester  city_Yatesbury  city_Youngbury  \
# 0            False               False           False           False
# 1            False               False           False           False
# 2            False               False           False           False
# 3            False               False           False           False
# 4            False               False           False           False
#
#    city_Yumouth  city_Zacharyton  city_Zamoramouth
# 0         False            False             False
# 1         False            False             False
# 2         False            False             False
# 3         False            False             False
# 4         False            False             False
#
# [5 rows x 3886 columns]

# %%
Y.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: loan_approved, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X,Y, train_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression 

model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# C:\Users\kauri\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, y_pred)
# Out:
# 0.851875

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
import joblib
joblib.dump(rf, "loan_model.pkl")
# Out:
# ['loan_model.pkl']

# %%
model = joblib.load("loan_model.pkl")
print(model)
# Out:
# RandomForestClassifier()

# %%
import joblib

joblib.dump(rf, "model/loan_model.pkl")
joblib.dump(X.columns, "model/model_columns.pkl")
# Out:
# ['model/model_columns.pkl']

# %%
import joblib

model = joblib.load("model/loan_model.pkl")
columns = joblib.load("model/model_columns.pkl")
